# %%
from f1_analysis.data_loader import load_session
import pandas as pd

session = load_session(2024, "Silverstone", "R")

results = session.results
results.iloc[0][["FullName", "Position", "TeamName","Points", "Time"]]
laps = session.laps
# Out:
# core           INFO 	Loading data for British Grand Prix - Race [v3.8.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 10)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '1', '4', '81', '55', '27', '18', '14', '23', '22', '2', '20', '3', '16', '77', '31', '11', '24', '63', '10']

# %%
laps.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate'],
#       dtype='object')

# %%
fastest_laps = laps.groupby('Driver').apply(
    lambda x: x.loc[x['LapTime'].idxmin()] if len(x) > 0 else None
) 

# Sort by lap time
fastest_laps = fastest_laps.sort_values('LapTime')
print(fastest_laps)
# Out:
#                          Time Driver DriverNumber                LapTime  \
# Driver
# RUS    0 days 01:23:01.707000    RUS           63 0 days 00:01:25.819000
# HAM    0 days 01:22:50.177000    HAM           44 0 days 00:01:25.990000
# NOR    0 days 01:14:34.691000    NOR            4 0 days 00:01:26.030000
# VER    0 days 01:22:38.775000    VER            1 0 days 00:01:26.203000
# PIA    0 days 01:14:22.585000    PIA           81 0 days 00:01:26.237000
# HUL    0 days 01:22:30.054000    HUL           27 0 days 00:01:26.338000
# SAI    0 days 01:14:44.976000    SAI           55 0 days 00:01:26.509000
# STR    0 days 01:22:20.331000    STR           18 0 days 00:01:26.585000
# ALB    0 days 01:22:11.911000    ALB           23 0 days 00:01:26.640000
# ALO    0 days 01:02:29.709000    ALO           14 0 days 00:01:26.730000
# LEC    0 days 01:02:07.073000    LEC           16 0 days 00:01:27.097000
# SAR    0 days 00:59:10.892000    SAR            2 0 days 00:01:27.175000
# TSU    0 days 01:02:20.217000    TSU           22 0 days 00:01:27.269000
# ZHO    0 days 00:59:28.684000    ZHO           24 0 days 00:01:27.867000
# RIC    0 days 01:03:08.596000    RIC            3 0 days 00:01:27.949000
# BOT    0 days 00:35:02.950000    BOT           77 0 days 00:01:32.431000
# MAG    0 days 00:35:16.945000    MAG           20 0 days 00:01:32.905000
# OCO    0 days 00:37:40.803000    OCO           31 0 days 00:01:34.557000
# PER    0 days 00:17:50.753000    PER           11 0 days 00:01:38.348000
# GAS    0 days 00:17:25.085000    GAS           10 0 days 00:01:39.804000
#
#         LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# Driver
# RUS          25.0    7.0        NaT       NaT 0 days 00:00:28.016000
# HAM          24.0    7.0        NaT       NaT 0 days 00:00:27.990000
# NOR          19.0    5.0        NaT       NaT 0 days 00:00:28.025000
# VER          23.0    6.0        NaT       NaT 0 days 00:00:28.136000
# PIA          20.0    5.0        NaT       NaT 0 days 00:00:28.043000
# HUL          16.0    5.0        NaT       NaT 0 days 00:00:27.886000
# SAI          20.0    6.0        NaT       NaT 0 days 00:00:28.009000
# STR          23.0    6.0        NaT       NaT 0 days 00:00:27.892000
# ALB          22.0    7.0        NaT       NaT 0 days 00:00:28.004000
# ALO          18.0    5.0        NaT       NaT 0 days 00:00:28.136000
# LEC          17.0    5.0        NaT       NaT 0 days 00:00:28.117000
# SAR          17.0    5.0        NaT       NaT 0 days 00:00:28.251000
# TSU          16.0    5.0        NaT       NaT 0 days 00:00:28.115000
# ZHO          19.0    5.0        NaT       NaT 0 days 00:00:28.252000
# RIC          17.0    5.0        NaT       NaT 0 days 00:00:28.418000
# BOT           8.0    3.0        NaT       NaT 0 days 00:00:29.149000
# MAG           5.0    2.0        NaT       NaT 0 days 00:00:29.587000
# OCO           9.0    3.0        NaT       NaT 0 days 00:00:30.569000
# PER           2.0    1.0        NaT       NaT 0 days 00:00:31.119000
# GAS           2.0    1.0        NaT       NaT 0 days 00:00:31.617000
#
#                   Sector2Time  ... FreshTyre             Team  \
# Driver                         ...
# RUS    0 days 00:00:34.508000  ...      True         Mercedes
# HAM    0 days 00:00:34.618000  ...      True         Mercedes
# NOR    0 days 00:00:34.567000  ...      True          McLaren
# VER    0 days 00:00:34.587000  ...      True  Red Bull Racing
# PIA    0 days 00:00:34.701000  ...      True          McLaren
# HUL    0 days 00:00:34.783000  ...      True     Haas F1 Team
# SAI    0 days 00:00:34.891000  ...      True          Ferrari
# STR    0 days 00:00:34.941000  ...      True     Aston Martin
# ALB    0 days 00:00:34.999000  ...      True         Williams
# ALO    0 days 00:00:34.915000  ...     False     Aston Martin
# LEC    0 days 00:00:35.160000  ...      True          Ferrari
# SAR    0 days 00:00:35.129000  ...     False         Williams
# TSU    0 days 00:00:35.163000  ...      True               RB
# ZHO    0 days 00:00:35.594000  ...      True      Kick Sauber
# RIC    0 days 00:00:35.594000  ...     False               RB
# BOT    0 days 00:00:37.552000  ...      True      Kick Sauber
# MAG    0 days 00:00:37.446000  ...      True     Haas F1 Team
# OCO    0 days 00:00:38.201000  ...      True           Alpine
# PER    0 days 00:00:39.482000  ...      True  Red Bull Racing
# GAS    0 days 00:00:40.506000  ...      True           Alpine
#
#                  LapStartTime            LapStartDate  TrackStatus  Position  \
# Driver
# RUS    0 days 01:21:35.888000 2024-07-06 15:08:48.897            1       NaN
# HAM    0 days 01:21:24.187000 2024-07-06 15:08:37.196            1       NaN
# NOR    0 days 01:13:08.661000 2024-07-06 15:00:21.670            1       NaN
# VER    0 days 01:21:12.572000 2024-07-06 15:08:25.581            1       NaN
# PIA    0 days 01:12:56.348000 2024-07-06 15:00:09.357            1       NaN
# HUL    0 days 01:21:03.716000 2024-07-06 15:08:16.725            1       NaN
# SAI    0 days 01:13:18.467000 2024-07-06 15:00:31.476            1       NaN
# STR    0 days 01:20:53.746000 2024-07-06 15:08:06.755            1       NaN
# ALB    0 days 01:20:45.271000 2024-07-06 15:07:58.280            1       NaN
# ALO    0 days 01:01:02.979000 2024-07-06 14:48:15.988            1       NaN
# LEC    0 days 01:00:39.976000 2024-07-06 14:47:52.985            1       NaN
# SAR    0 days 00:57:43.717000 2024-07-06 14:44:56.726            1       NaN
# TSU    0 days 01:00:52.948000 2024-07-06 14:48:05.957            1       NaN
# ZHO    0 days 00:58:00.817000 2024-07-06 14:45:13.826            1       NaN
# RIC    0 days 01:01:40.647000 2024-07-06 14:48:53.656            1       NaN
# BOT    0 days 00:33:30.519000 2024-07-06 14:20:43.528            1       NaN
# MAG    0 days 00:33:44.040000 2024-07-06 14:20:57.049            1       NaN
# OCO    0 days 00:36:06.246000 2024-07-06 14:23:19.255            1       NaN
# PER    0 days 00:16:12.405000 2024-07-06 14:03:25.414            1       NaN
# GAS    0 days 00:15:45.281000 2024-07-06 14:02:58.290            1       NaN
#
#         Deleted  DeletedReason  FastF1Generated IsAccurate
# Driver
# RUS       False                           False       True
# HAM       False                           False       True
# NOR       False                           False       True
# VER       False                           False       True
# PIA       False                           False       True
# HUL       False                           False       True
# SAI       False                           False       True
# STR       False                           False       True
# ALB       False                           False       True
# ALO       False                           False       True
# LEC       False                           False       True
# SAR       False                           False       True
# TSU       False                           False       True
# ZHO       False                           False       True
# RIC       False                           False       True
# BOT       False                           False       True
# MAG       False                           False       True
# OCO       False                           False       True
# PER       False                           False       True
# GAS       False                           False       True
#
# [20 rows x 31 columns]
# /var/folders/xp/dq54phqn5ql82xq1ml3dw0gm0000gn/T/ipykernel_79096/4138501050.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   fastest_laps = laps.groupby('Driver').apply(

# %%
oscar = laps.pick_drivers("PIA").copy() 
lando = laps.pick_drivers("NOR").copy()
oscar["LapTimeSeconds"] = oscar["LapTime"].dt.total_seconds()

lando["LapTimeSeconds"] = lando["LapTime"].dt.total_seconds()
delta = (
    oscar["LapTimeSeconds"].reset_index(drop=True)
    - lando["LapTimeSeconds"].reset_index(drop=True)
)
for value in delta:
    if value < 0:
        print(f"Norris was {round(value, 3)} faster than Piastri")
    else:
        print(f"Norris was +{round(value, 3)} slower than Piastri")
# Out:
# Norris was +0.661 slower than Piastri
# Norris was +0.173 slower than Piastri
# Norris was -0.064 faster than Piastri
# Norris was -0.057 faster than Piastri
# Norris was +0.116 slower than Piastri
# Norris was +0.166 slower than Piastri
# Norris was -0.146 faster than Piastri
# Norris was -0.024 faster than Piastri
# Norris was +0.024 slower than Piastri
# Norris was -0.019 faster than Piastri
# Norris was +0.107 slower than Piastri
# Norris was -0.055 faster than Piastri
# Norris was +0.424 slower than Piastri
# Norris was +0.29 slower than Piastri
# Norris was +0.568 slower than Piastri
# Norris was +0.428 slower than Piastri
# Norris was -0.316 faster than Piastri
# Norris was +0.144 slower than Piastri
# Norris was -0.708 faster than Piastri
# Norris was -0.356 faster than Piastri
# Norris was +0.306 slower than Piastri
# Norris was +0.309 slower than Piastri
# Norris was -0.2 faster than Piastri
# Norris was -0.237 faster than Piastri
# Norris was -0.036 faster than Piastri
# Norris was -0.893 faster than Piastri
# Norris was +4.941 slower than Piastri
# Norris was -7.939 faster than Piastri
# Norris was +20.918 slower than Piastri
# Norris was -0.225 faster than Piastri
# Norris was +0.848 slower than Piastri
# Norris was +0.921 slower than Piastri
# Norris was +0.718 slower than Piastri
# Norris was +0.876 slower than Piastri
# Norris was +0.374 slower than Piastri
# Norris was +0.18 slower than Piastri
# Norris was -0.151 faster than Piastri
# Norris was -0.893 faster than Piastri
# Norris was +17.912 slower than Piastri
# Norris was -24.927 faster than Piastri
# Norris was -0.159 faster than Piastri
# Norris was -0.425 faster than Piastri
# Norris was +0.024 slower than Piastri
# Norris was -0.531 faster than Piastri
# Norris was -0.413 faster than Piastri
# Norris was -0.727 faster than Piastri
# Norris was -0.789 faster than Piastri
# Norris was -1.432 faster than Piastri
# Norris was -1.232 faster than Piastri
# Norris was -0.586 faster than Piastri
# Norris was -2.021 faster than Piastri
# Norris was -0.985 faster than Piastri

# %%
d = laps.pick_drivers("HAM")
d["PitInTime"]
# Out:
# 0                       NaT
# 1                       NaT
# 2                       NaT
# 3                       NaT
# 4                       NaT
# 5                       NaT
# 6                       NaT
# 7                       NaT
# 8                       NaT
# 9                       NaT
# 10                      NaT
# 11                      NaT
# 12                      NaT
# 13                      NaT
# 14                      NaT
# 15                      NaT
# 16                      NaT
# 17                      NaT
# 18                      NaT
# 19                      NaT
# 20                      NaT
# 21                      NaT
# 22                      NaT
# 23                      NaT
# 24                      NaT
# 25                      NaT
# 26   0 days 01:40:20.422000
# 27                      NaT
# 28                      NaT
# 29                      NaT
# 30                      NaT
# 31                      NaT
# 32                      NaT
# 33                      NaT
# 34                      NaT
# 35                      NaT
# 36                      NaT
# 37   0 days 01:59:12.470000
# 38                      NaT
# 39                      NaT
# 40                      NaT
# 41                      NaT
# 42                      NaT
# 43                      NaT
# 44                      NaT
# 45                      NaT
# 46                      NaT
# 47                      NaT
# 48                      NaT
# 49                      NaT
# 50                      NaT
# 51                      NaT
# Name: PitInTime, dtype: timedelta64[ns]
