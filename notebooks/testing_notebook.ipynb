# %%
from f1_analysis.data_loader import load_session

year = 2024
race = "Silverstone"
gp_session = "R"

session = load_session(year, race, gp_session)
print(session.laps)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from f1_analysis.data_loader import load_session
#       2
#       3 year = 2024
#       4 race = "Silverstone"
#
# ModuleNotFoundError: No module named 'f1_analysis'
